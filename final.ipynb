# %%
# !pip install textblob
# Out:
# Collecting textblob
#   Using cached textblob-0.15.3-py2.py3-none-any.whl (636 kB)
# Processing /home/jmulagi/.cache/pip/wheels/ff/d5/7b/f1fb4e1e1603b2f01c2424dd60fbcc50c12ef918bafc44b155/nltk-3.5-py3-none-any.whl
# Collecting click
#   Using cached click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting regex
#   Using cached regex-2021.3.17-cp38-cp38-manylinux2014_x86_64.whl (737 kB)
# Collecting tqdm
#   Using cached tqdm-4.59.0-py2.py3-none-any.whl (74 kB)
# Collecting joblib
#   Using cached joblib-1.0.1-py3-none-any.whl (303 kB)
# Installing collected packages: click, regex, tqdm, joblib, nltk, textblob
# Successfully installed click-7.1.2 joblib-1.0.1 nltk-3.5 regex-2021.3.17 textblob-0.15.3 tqdm-4.59.0

# %%
# !pip install tweepy
# Out:
# Collecting tweepy
#   Using cached tweepy-3.10.0-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: six>=1.10.0 in ./jackson_env/lib/python3.8/site-packages (from tweepy) (1.15.0)
# Collecting requests[socks]>=2.11.1
#   Using cached requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Using cached urllib3-1.26.4-py2.py3-none-any.whl (153 kB)
# Collecting idna<3,>=2.5
#   Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting chardet<5,>=3.0.2
#   Using cached chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2020.12.5-py2.py3-none-any.whl (147 kB)
# Collecting PySocks!=1.5.7,>=1.5.6; extra == "socks"
#   Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Installing collected packages: urllib3, idna, chardet, certifi, PySocks, requests, oauthlib, requests-oauthlib, tweepy
# Successfully installed PySocks-1.7.1 certifi-2020.12.5 chardet-4.0.0 idna-2.10 oauthlib-3.1.0 requests-2.25.1 requests-oauthlib-1.3.0 tweepy-3.10.0 urllib3-1.26.4

# %%
from textblob import TextBlob

# %%
import sys

# %%
import tweepy

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-a0d2faabd9e9> in <module>
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in ./jackson_env/lib/python3.8/site-packages (3.4.1)
# Requirement already satisfied: pillow>=6.2.0 in ./jackson_env/lib/python3.8/site-packages (from matplotlib) (8.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in ./jackson_env/lib/python3.8/site-packages (from matplotlib) (2.8.1)
# Requirement already satisfied: cycler>=0.10 in ./jackson_env/lib/python3.8/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: numpy>=1.16 in ./jackson_env/lib/python3.8/site-packages (from matplotlib) (1.20.2)
# Requirement already satisfied: pyparsing>=2.2.1 in ./jackson_env/lib/python3.8/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./jackson_env/lib/python3.8/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: six>=1.5 in ./jackson_env/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in ./jackson_env/lib/python3.8/site-packages (1.2.3)
# Requirement already satisfied: numpy>=1.16.5 in ./jackson_env/lib/python3.8/site-packages (from pandas) (1.20.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in ./jackson_env/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in ./jackson_env/lib/python3.8/site-packages (from pandas) (2021.1)
# Requirement already satisfied: six>=1.5 in ./jackson_env/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
import numpy as np

# %%
import os

# %%
import nltk

# %%
# !pip install pycountry
# Out:
# Processing /home/jmulagi/.cache/pip/wheels/09/eb/0d/4ee773c6a4aadc2a43cb5c1d07f268f13c4cdc0eec88e7c1ef/pycountry-20.7.3-py2.py3-none-any.whl
# Installing collected packages: pycountry
# Successfully installed pycountry-20.7.3

# %%
import pycountry

# %%
import re

# %%
import string

# %%
from wordcloud import WordCloud, STOPWORDS
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-09aeca815748> in <module>
# ----> 1 from wordcloud import WordCloud, STOPWORDS
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Using cached wordcloud-1.8.1-cp38-cp38-manylinux1_x86_64.whl (371 kB)
# Requirement already satisfied: pillow in ./jackson_env/lib/python3.8/site-packages (from wordcloud) (8.2.0)
# Requirement already satisfied: matplotlib in ./jackson_env/lib/python3.8/site-packages (from wordcloud) (3.4.1)
# Requirement already satisfied: numpy>=1.6.1 in ./jackson_env/lib/python3.8/site-packages (from wordcloud) (1.20.2)
# Requirement already satisfied: pyparsing>=2.2.1 in ./jackson_env/lib/python3.8/site-packages (from matplotlib->wordcloud) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./jackson_env/lib/python3.8/site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in ./jackson_env/lib/python3.8/site-packages (from matplotlib->wordcloud) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in ./jackson_env/lib/python3.8/site-packages (from matplotlib->wordcloud) (2.8.1)
# Requirement already satisfied: six in ./jackson_env/lib/python3.8/site-packages (from cycler>=0.10->matplotlib->wordcloud) (1.15.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.1

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
from PIL import Image

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
# !pip install langdetect
# Out:
# Processing /home/jmulagi/.cache/pip/wheels/1e/80/23/0a24928ec3a3906ff5027f38d2fea824e7e97f2ba7c83d91e3/langdetect-1.0.8-py3-none-any.whl
# Requirement already satisfied: six in ./jackson_env/lib/python3.8/site-packages (from langdetect) (1.15.0)
# Installing collected packages: langdetect
# Successfully installed langdetect-1.0.8

# %%
from langdetect import detect

# %%
import pandas as pd

# %%
import pycountry

# %%
from langdetect import detect

# %%
from nltk.stem import SnowballStemmer

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
from sklearn.feature_extraction.text import CountVectorizer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-28-6a1df9f4b4e2> in <module>
# ----> 1 from sklearn.feature_extraction.text import CountVectorizer
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# !pip install sklearn
# Out:
# Processing /home/jmulagi/.cache/pip/wheels/22/0b/40/fd3f795caaa1fb4c6cb738bc1f56100be1e57da95849bfc897/sklearn-0.0-py2.py3-none-any.whl
# Collecting scikit-learn
#   Using cached scikit_learn-0.24.1-cp38-cp38-manylinux2010_x86_64.whl (24.9 MB)
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: numpy>=1.13.3 in ./jackson_env/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.20.2)
# Collecting scipy>=0.19.1
#   Using cached scipy-1.6.2-cp38-cp38-manylinux1_x86_64.whl (27.2 MB)
# Requirement already satisfied: joblib>=0.11 in ./jackson_env/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.0.1)
# Installing collected packages: threadpoolctl, scipy, scikit-learn, sklearn
# Successfully installed scikit-learn-0.24.1 scipy-1.6.2 sklearn-0.0 threadpoolctl-2.1.0

# %%
consumerKey = "zDnewuMZKH1jyJFZFbVAtmCbw"
consumerSecret = "G0thazaQ1gCtFxEPCpoHUq5Fe6iWogQmS7hmjJeAEVv5xIXDfR"
accessToken = "1183387752-ZZELnVtw739OWWJBD65WhXmEsGGsmJ82WyIVI1N"
accessTokenSecret = "QFKQACGCQRPzV5IMzY6VPhZ0H3jyok5inpUnkO1tfMwuB"

auth = tweepy.OAuthHandler(consumerKey, consumerSecret)
auth.set_access_token(accessToken, accessTokenSecret)
api = tweepy.API(auth)

# %%
#Sentiment Analysis

def percentage(part,whole):
    return 100 * float(part)/float(whole) 

keyword = input("Please enter keyword or hashtag to search: ")
noOfTweet = int(input ("Please enter how many tweets to analyze: "))


tweets = tweepy.Cursor(api.search, q=keyword).items(noOfTweet)
positive  = 0
negative = 0
neutral = 0
polarity = 0
tweet_list = []
neutral_list = []
negative_list = []
positive_list = []

for tweet in tweets:
    
    #print(tweet.text)
    tweet_list.append(tweet.text)
    analysis = TextBlob(tweet.text)
    score = SentimentIntensityAnalyzer().polarity_scores(tweet.text)
    neg = score['neg']
    neu = score['neu']
    pos = score['pos']
    comp = score['compound']
    polarity += analysis.sentiment.polarity
    
    if neg > pos:
        negative_list.append(tweet.text)
        negative += 1

    elif pos > neg:
        positive_list.append(tweet.text)
        positive += 1
    
    elif pos == neg:
        neutral_list.append(tweet.text)
        neutral += 1

positive = percentage(positive, noOfTweet)
negative = percentage(negative, noOfTweet)
neutral = percentage(neutral, noOfTweet)
polarity = percentage(polarity, noOfTweet)
positive = format(positive, '.1f')
negative = format(negative, '.1f')
neutral = format(neutral, '.1f')
# Out:
# Please enter keyword or hashtag to search: Airbnb
# Please enter how many tweets to analyze: 20

# %%
#Number of Tweets (Total, Positive, Negative, Neutral)
tweet_list = pd.DataFrame(tweet_list)
neutral_list = pd.DataFrame(neutral_list)
negative_list = pd.DataFrame(negative_list)
positive_list = pd.DataFrame(positive_list)
print("total number: ",len(tweet_list))
print("positive number: ",len(positive_list))
print("negative number: ", len(negative_list))
print("neutral number: ",len(neutral_list))
# Out:
# total number:  20
# positive number:  6
# negative number:  1
# neutral number:  13

# %%
tweet_list
# Out:
#                                                     0
# 0   RT @RichavelIi: My boy Airbnb his crib out rig...
# 1   RT @SokoAnalyst: If you own an Airbnb/Homestay...
# 2   RT @SokoAnalyst: If you own an Airbnb/Homestay...
# 3   RT @robisearch: We offer the best Bulk SMS tha...
# 4   RT @SokoAnalyst: If you own an Airbnb/Homestay...
# 5   @MileyCyrus @CashApp $BrianSurasky let’s go wi...
# 6   RT @dulcet_ke: By the way if you own an Airbnb...
# 7   If you own an Airbnb/Homestay\n\nYou'll be pay...
# 8   RT @robisearch: We offer the best Bulk SMS tha...
# 9   RT @Asinastra: Кот по имени элиот, который шел...
# 10  RT @dulcet_ke: By the way if you own an Airbnb...
# 11  RT @leleti____: Prevent theft &amp; increase a...
# 12  RT @richu_jay: It's a #GoodFriday and everyone...
# 13  RT @CollinsKaranja3: Now that the prices for A...
# 14  RT @cibersonora: ⚠️Si quieres rentar un alojam...
# 15  I see you there, brilliant bizness idea, brill...
# 16  https://t.co/FyQEjYgIcZ Streamline the communi...
# 17  RT @SafinaSacho: The Kenyan government is kill...
# 18  dapet recehan dari yg jadi booking airbnb aja ...
# 19  いままでビジネスとかうさんくさいって思ってたし、友達に誘われても全部断ってた、、、\n\n固...

# %%
labels = ['Positive ['+str(positive)+'%]' , 'Neutral ['+str(neutral)+'%]','Negative ['+str(negative)+'%]']
sizes = [positive, neutral, negative]
colors = ['yellowgreen', 'blue','red']
patches, texts = plt.pie(sizes,colors=colors, startangle=90)
plt.style.use('default')
plt.legend(labels)
plt.title("Sentiment Analysis Result for keyword=  "+keyword+"" )
plt.axis('equal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-57fc40dda968> in <module>
#       2 sizes = [positive, neutral, negative]
#       3 colors = ['yellowgreen', 'blue','red']
# ----> 4 patches, texts = plt.pie(sizes,colors=colors, startangle=90)
#       5 plt.style.use('default')
#       6 plt.legend(labels)
#
# NameError: name 'plt' is not defined

# %%
#Creating PieCart

labels = ['Positive ['+str(positive)+'%]' , 'Neutral ['+str(neutral)+'%]','Negative ['+str(negative)+'%]']
sizes = [positive, neutral, negative]
colors = ['yellowgreen', 'blue','red']
patches, texts = plt.pie(sizes,colors=colors, startangle=90)
plt.style.use('default')
plt.legend(labels)
plt.title("Sentiment Analysis Result for keyword=  "+keyword+"" )
plt.axis('equal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-9b7988da67fe> in <module>
#       4 sizes = [positive, neutral, negative]
#       5 colors = ['yellowgreen', 'blue','red']
# ----> 6 patches, texts = plt.pie(sizes,colors=colors, startangle=90)
#       7 plt.style.use('default')
#       8 plt.legend(labels)
#
# NameError: name 'plt' is not defined

# %%
tweet_list.drop_duplicates(inplace = True)

# %%
tw_list = pd.DataFrame(tweet_list)
tw_list["text"] = tw_list[0]
tw_list
# Out:
#                                                     0  \
# 0   RT @RichavelIi: My boy Airbnb his crib out rig...
# 1   RT @SokoAnalyst: If you own an Airbnb/Homestay...
# 3   RT @robisearch: We offer the best Bulk SMS tha...
# 5   @MileyCyrus @CashApp $BrianSurasky let’s go wi...
# 6   RT @dulcet_ke: By the way if you own an Airbnb...
# 7   If you own an Airbnb/Homestay\n\nYou'll be pay...
# 9   RT @Asinastra: Кот по имени элиот, который шел...
# 11  RT @leleti____: Prevent theft &amp; increase a...
# 12  RT @richu_jay: It's a #GoodFriday and everyone...
# 13  RT @CollinsKaranja3: Now that the prices for A...
# 14  RT @cibersonora: ⚠️Si quieres rentar un alojam...
# 15  I see you there, brilliant bizness idea, brill...
# 16  https://t.co/FyQEjYgIcZ Streamline the communi...
# 17  RT @SafinaSacho: The Kenyan government is kill...
# 18  dapet recehan dari yg jadi booking airbnb aja ...
# 19  いままでビジネスとかうさんくさいって思ってたし、友達に誘われても全部断ってた、、、\n\n固...
#
#                                                  text
# 0   RT @RichavelIi: My boy Airbnb his crib out rig...
# 1   RT @SokoAnalyst: If you own an Airbnb/Homestay...
# 3   RT @robisearch: We offer the best Bulk SMS tha...
# 5   @MileyCyrus @CashApp $BrianSurasky let’s go wi...
# 6   RT @dulcet_ke: By the way if you own an Airbnb...
# 7   If you own an Airbnb/Homestay\n\nYou'll be pay...
# 9   RT @Asinastra: Кот по имени элиот, который шел...
# 11  RT @leleti____: Prevent theft &amp; increase a...
# 12  RT @richu_jay: It's a #GoodFriday and everyone...
# 13  RT @CollinsKaranja3: Now that the prices for A...
# 14  RT @cibersonora: ⚠️Si quieres rentar un alojam...
# 15  I see you there, brilliant bizness idea, brill...
# 16  https://t.co/FyQEjYgIcZ Streamline the communi...
# 17  RT @SafinaSacho: The Kenyan government is kill...
# 18  dapet recehan dari yg jadi booking airbnb aja ...
# 19  いままでビジネスとかうさんくさいって思ってたし、友達に誘われても全部断ってた、、、\n\n固...

# %%
tweet_list
# Out:
#                                                     0  \
# 0   RT @RichavelIi: My boy Airbnb his crib out rig...
# 1   RT @SokoAnalyst: If you own an Airbnb/Homestay...
# 3   RT @robisearch: We offer the best Bulk SMS tha...
# 5   @MileyCyrus @CashApp $BrianSurasky let’s go wi...
# 6   RT @dulcet_ke: By the way if you own an Airbnb...
# 7   If you own an Airbnb/Homestay\n\nYou'll be pay...
# 9   RT @Asinastra: Кот по имени элиот, который шел...
# 11  RT @leleti____: Prevent theft &amp; increase a...
# 12  RT @richu_jay: It's a #GoodFriday and everyone...
# 13  RT @CollinsKaranja3: Now that the prices for A...
# 14  RT @cibersonora: ⚠️Si quieres rentar un alojam...
# 15  I see you there, brilliant bizness idea, brill...
# 16  https://t.co/FyQEjYgIcZ Streamline the communi...
# 17  RT @SafinaSacho: The Kenyan government is kill...
# 18  dapet recehan dari yg jadi booking airbnb aja ...
# 19  いままでビジネスとかうさんくさいって思ってたし、友達に誘われても全部断ってた、、、\n\n固...
#
#                                                  text
# 0   RT @RichavelIi: My boy Airbnb his crib out rig...
# 1   RT @SokoAnalyst: If you own an Airbnb/Homestay...
# 3   RT @robisearch: We offer the best Bulk SMS tha...
# 5   @MileyCyrus @CashApp $BrianSurasky let’s go wi...
# 6   RT @dulcet_ke: By the way if you own an Airbnb...
# 7   If you own an Airbnb/Homestay\n\nYou'll be pay...
# 9   RT @Asinastra: Кот по имени элиот, который шел...
# 11  RT @leleti____: Prevent theft &amp; increase a...
# 12  RT @richu_jay: It's a #GoodFriday and everyone...
# 13  RT @CollinsKaranja3: Now that the prices for A...
# 14  RT @cibersonora: ⚠️Si quieres rentar un alojam...
# 15  I see you there, brilliant bizness idea, brill...
# 16  https://t.co/FyQEjYgIcZ Streamline the communi...
# 17  RT @SafinaSacho: The Kenyan government is kill...
# 18  dapet recehan dari yg jadi booking airbnb aja ...
# 19  いままでビジネスとかうさんくさいって思ってたし、友達に誘われても全部断ってた、、、\n\n固...

# %%
#Cleaning Text (RT, Punctuation etc)

#Creating new dataframe and new features
tw_list = pd.DataFrame(tweet_list)
tw_list["text"] = tw_list[0]

#Removing RT, Punctuation etc
remove_rt = lambda x: re.sub('RT @\w+: '," ",x)
rt = lambda x: re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",x)
tw_list["text"] = tw_list.text.map(remove_rt).map(rt)
tw_list["text"] = tw_list.text.str.lower()
tw_list.head(10)
# Out:
#                                                     0  \
# 0   RT @RichavelIi: My boy Airbnb his crib out rig...
# 1   RT @SokoAnalyst: If you own an Airbnb/Homestay...
# 3   RT @robisearch: We offer the best Bulk SMS tha...
# 5   @MileyCyrus @CashApp $BrianSurasky let’s go wi...
# 6   RT @dulcet_ke: By the way if you own an Airbnb...
# 7   If you own an Airbnb/Homestay\n\nYou'll be pay...
# 9   RT @Asinastra: Кот по имени элиот, который шел...
# 11  RT @leleti____: Prevent theft &amp; increase a...
# 12  RT @richu_jay: It's a #GoodFriday and everyone...
# 13  RT @CollinsKaranja3: Now that the prices for A...
#
#                                                  text
# 0    my boy airbnb his crib out right  iight so bo...
# 1    if you own an airbnb homestay government want...
# 3    we offer the best bulk sms that helps you dri...
# 5        briansurasky let s go with airbnb big yea...
# 6    by the way if you own an airbnb homestay gove...
# 7   if you own an airbnb homestay  you ll be payin...
# 9                                                 ...
# 11   prevent theft  amp  increase accountability i...
# 12   it s a  goodfriday and everyone deserves a go...
# 13   now that the prices for airbnb are about to s...

# %%
#Calculating Negative, Positive, Neutral and Compound values

tw_list[['polarity', 'subjectivity']] = tw_list['text'].apply(lambda Text: pd.Series(TextBlob(Text).sentiment))
for index, row in tw_list['text'].iteritems():
    score = SentimentIntensityAnalyzer().polarity_scores(row)
    neg = score['neg']
    neu = score['neu']
    pos = score['pos']
    comp = score['compound']
    if neg > pos:
        tw_list.loc[index, 'sentiment'] = "negative"
    elif pos > neg:
        tw_list.loc[index, 'sentiment'] = "positive"
    else:
        tw_list.loc[index, 'sentiment'] = "neutral"
    tw_list.loc[index, 'neg'] = neg
    tw_list.loc[index, 'neu'] = neu
    tw_list.loc[index, 'pos'] = pos
    tw_list.loc[index, 'compound'] = comp

tw_list.head(50)
# Out:
#                                                     0  \
# 0   RT @RichavelIi: My boy Airbnb his crib out rig...
# 1   RT @SokoAnalyst: If you own an Airbnb/Homestay...
# 3   RT @robisearch: We offer the best Bulk SMS tha...
# 5   @MileyCyrus @CashApp $BrianSurasky let’s go wi...
# 6   RT @dulcet_ke: By the way if you own an Airbnb...
# 7   If you own an Airbnb/Homestay\n\nYou'll be pay...
# 9   RT @Asinastra: Кот по имени элиот, который шел...
# 11  RT @leleti____: Prevent theft &amp; increase a...
# 12  RT @richu_jay: It's a #GoodFriday and everyone...
# 13  RT @CollinsKaranja3: Now that the prices for A...
# 14  RT @cibersonora: ⚠️Si quieres rentar un alojam...
# 15  I see you there, brilliant bizness idea, brill...
# 16  https://t.co/FyQEjYgIcZ Streamline the communi...
# 17  RT @SafinaSacho: The Kenyan government is kill...
# 18  dapet recehan dari yg jadi booking airbnb aja ...
# 19  いままでビジネスとかうさんくさいって思ってたし、友達に誘われても全部断ってた、、、\n\n固...
#
#                                                  text  polarity  subjectivity  \
# 0    my boy airbnb his crib out right  iight so bo...  0.142857      0.767857
# 1    if you own an airbnb homestay government want...  0.400000      0.550000
# 3    we offer the best bulk sms that helps you dri...  0.500000      0.328571
# 5        briansurasky let s go with airbnb big yea...  0.000000      0.100000
# 6    by the way if you own an airbnb homestay gove...  0.400000      0.550000
# 7   if you own an airbnb homestay  you ll be payin...  0.600000      1.000000
# 9                                                 ...  0.000000      0.000000
# 11   prevent theft  amp  increase accountability i...  0.000000      0.000000
# 12   it s a  goodfriday and everyone deserves a go...  0.633333      0.800000
# 13   now that the prices for airbnb are about to s...  0.200000      0.400000
# 14     si quieres rentar un alojamiento  real zalo...  0.200000      0.300000
# 15  i see you there  brilliant bizness idea  brill...  0.900000      1.000000
# 16    streamline the communication process in your...  0.000000      0.000000
# 17   the kenyan government is killing its people s...  0.750000      0.950000
# 18  dapet recehan dari yg jadi booking airbnb aja ...  0.000000      0.000000
# 19                                                ...  0.000000      0.000000
#
#    sentiment    neg    neu    pos  compound
# 0    neutral  0.000  1.000  0.000    0.0000
# 1    neutral  0.000  1.000  0.000    0.0000
# 3   positive  0.000  0.651  0.349    0.8442
# 5    neutral  0.000  1.000  0.000    0.0000
# 6    neutral  0.000  1.000  0.000    0.0000
# 7   negative  0.153  0.847  0.000   -0.5574
# 9    neutral  0.000  1.000  0.000    0.0000
# 11  positive  0.000  0.747  0.253    0.6249
# 12  positive  0.000  0.586  0.414    0.8720
# 13  positive  0.000  0.816  0.184    0.5574
# 14   neutral  0.000  1.000  0.000    0.0000
# 15  positive  0.110  0.587  0.303    0.6059
# 16   neutral  0.000  1.000  0.000    0.0000
# 17  negative  0.179  0.691  0.130   -0.2960
# 18   neutral  0.000  1.000  0.000    0.0000
# 19   neutral  0.000  1.000  0.000    0.0000

# %%
#Creating new data frames for all sentiments (positive, negative and neutral)

tw_list_negative = tw_list[tw_list["sentiment"]=="negative"]
tw_list_positive = tw_list[tw_list["sentiment"]=="positive"]
tw_list_neutral = tw_list[tw_list["sentiment"]=="neutral"]

# %%
#Function for count_values_in single columns

def count_values_in_column(data,feature):
    total=data.loc[:,feature].value_counts(dropna=False)
    percentage=round(data.loc[:,feature].value_counts(dropna=False,normalize=True)*100,2)
    return pd.concat([total,percentage],axis=1,keys=['Total','Percentage'])

# %%
#Count_values for sentiment
count_values_in_column(tw_list,"sentiment")
# Out:
#           Total  Percentage
# neutral       9       56.25
# positive      5       31.25
# negative      2       12.50
